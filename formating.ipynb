# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 364.6 kB/s eta 0:00:26
#    --- ------------------------------------ 0.8/9.7 MB 524.3 kB/s eta 0:00:18
#    --- ------------------------------------ 0.8/9.7 MB 524.3 kB/s eta 0:00:18
#    ---- ----------------------------------- 1.0/9.7 MB 636.8 kB/s eta 0:00:14
# ...

# %%
import pandas as pd

# %%
df =pd.read_csv('C:\\Users\\rijul\\OneDrive\\Desktop\\pandas\\Radiant Dental Care GMB Report_march.xlsx - GMB.csv')

# %%
df
# Out:
#                                         Business name  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Radiant Dental Care | Dental Clinic in Nangana...
# 3     Radiant Dental Care | Dental Clinic in Siruseri
# 4        Radiant Dental Care | Dental Clinic in Adyar
# 5     Radiant Dental Care | Dental Clinic in Chrompet
# 6   Radiant Dental Care | Dental Clinic in Medavakkam
# 7   Radiant Dental Care | Dental Clinic in Guduvan...
# 8   Radiant Dental Care | Dental Clinic in Tambara...
# 9   Radiant Dental Care | Dental Clinic in Navalur...
# 10  Radiant Dental Care | Dental Clinic in Perungu...
#
#                                Google Search - Mobile Unnamed: 2  \
# 0   Number of people that viewed your Business Pro...        NaN
# 1                                            February      March
# 2                                                 610        745
# ...
